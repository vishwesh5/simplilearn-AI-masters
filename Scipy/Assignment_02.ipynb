# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/>
#
# # Assignment 02: Perform CDF and PDF
#
# *The comments/sections provided are your cues to perform the assignment. You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.*
#
# *If at any point in time you need help on solving this assignment, view our demo video to understand the different steps of the code.*
#
# **Happy coding!**
#
# * * *

# %% [markdown]
# #### 1: Import required library

# %%
import numpy as np
from scipy.stats import norm

# %% [markdown]
# #### 2: Perfrom Cumulative Distribution Function or CDF on variables, with loc 1 and scale 3

# %%
norm.rvs(loc=0,scale=1,size=20)
# Out:
# array([ 1.55272214, -0.46078687,  0.7455013 ,  0.02284461,  1.65594212,
#        -0.09682291,  0.68105531,  1.01756192,  0.20883641, -1.12243902,
#         1.58693955, -0.12427026, -3.11705808,  0.44108709, -0.36046857,
#        -0.26134817,  0.10629051, -0.00421412,  0.9764279 , -0.56338373])

# %%
norm.cdf(10,scale=3,loc=1)
# Out:
# 0.9986501019683699

# %% [markdown]
# #### 3: Perfrom Probability Density Function or PDF on variables, with loc 1 and scale 1

# %%
norm.pdf(14,scale=1,loc=1)
# Out:
# 7.998827757006813e-38
